# %%
# !python export_onnx.py --checkpoint ultimate_tiled_multitask_mobile.pth --output model.onnx --grid-cols 5 --grid-rows 4 --tile-size 256 --model-name convnextv2_nano.fcmae_ft_in22k_in1k_384
# Out:
# Loading checkpoint: ultimate_tiled_multitask_mobile.pth
# Creating model: convnextv2_nano.fcmae_ft_in22k_in1k_384
# Exporting with tile size: 256, grid: 5×4
# /workspace/app-builder-unido-africarice/RiceChallenge_final/submit.py:75: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if f32_up.shape != f16.shape:
# ONNX model exported to: model.onnx
# Model does not use external data (single-file .onnx).
# Final ONNX file size: 76.17 MB

# %%
import cv2
import matplotlib.pyplot as plt

plt.imshow(cv2.imread("/workspace/app-builder-unido-africarice/RiceChallenge_final/Data/images/images/ID_0AA188.png"))

# %%
import os; len(os.listdir("/workspace/app-builder-unido-africarice/RiceChallenge_final/Data/images/images"))
# Out:
# 1341
